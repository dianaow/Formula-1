# %% [markdown]
# ## Classification of Tyre Use Per Stint Per Driver for each race in 2017 season

# %%
import numpy as np
import scipy 
import scipy.stats
from scipy import stats
import seaborn as sns
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from itertools import groupby
import pickle
import os
import math
from sympy import S, symbols
from collections import Counter

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.style.use('fivethirtyeight')
#sns.mpl.rcParams['figure.figsize'] = (16, 10)

# Directory to store pickled dataframes
directory = '/Users/dianaow/Documents/formula-1-race-data/dataframes/'

# %%
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn import cross_validation
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, classification_report, recall_score, confusion_matrix
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.combine import SMOTETomek, SMOTEENN
from imblearn.under_sampling import TomekLinks
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
# Out:
# /Users/dianaow/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
palette = {"Ultra soft":"#9b59b6", 
           "Super soft":"#ff5745", 
           "Soft":"#edee3d", 
           "Medium":"#cccccc", 
           "Hard":"#ff9932",
           "Intermediate":"#00f164",
           "Wet":"#85c8fb",
           "None": "#fabebe"}

plt.style.use("dark_background")

# %%
def read_from_pickle(directory, filename):
    df = pd.DataFrame()
    filepath = directory + filename
    with open(filepath, 'rb') as file:
        df = pickle.load(file)
            
    return df

# %%
X_k = read_from_pickle(directory, "X_k.pickle")
clusters = read_from_pickle(directory, "clusters.pickle")
df_tyres = read_from_pickle(directory, "df_tyres.pickle")
drivers_2016 = read_from_pickle(directory, "drivers_2016.pickle")
drivers_2016t = read_from_pickle(directory, "drivers_2016t.pickle")

# %%
clusters16 = read_from_pickle(directory, "clusters16.pickle")

# %%
xl = pd.ExcelFile("./formula-1-race-data/Selected_Sets.xlsx", encoding='utf-8')
xl.sheet_names
selected_sets = xl.parse("Sheet10")

# %%
xl = pd.ExcelFile("./formula-1-race-data/Track_Information.xlsx", encoding='utf-8')
xl.sheet_names
track_info = xl.parse("Copy of Sheet12")

# %%
xl = pd.ExcelFile("/Users/dianaow/Downloads/F1_Tyre_data.xlsx")
xl.sheet_names
pirelli = xl.parse("Sheet7")

# %% [markdown]
# ### Features of the classification model:
# - Count of each tyre type selected for the race (teams select the number of tyres for their driver based on Pirelli's allocated mandatory tyre set)
# - Track Information
#     - 1) Average track temperature (from 2014 to 2017)
#     - 2) Range of Track Temperature(from 2014 to 2017)
#     - 3) Tyre Stress Rate
#     - 4) Downforce Rate
#     - 5) Asphalt Abrasion
#     - 6) Number of race laps
#     - 7) Circuit length
#
#
# - Cluster label based on the track's 2016 pit strategy records
# - Driver-specific multiplier for each tyre type (to account for the fact that different drivers wear out their tyres at different rates. Measured by calculating the total stint length each driver spent on each tyre type at each race track (only include completed stints), divided by the summed lengths of each stint)
#
# Data Sources:
# - https://racingspot.pirelli.com/global/en-ww/infographics
# - https://docs.google.com/spreadsheets/d/15A9gs4X3vIPpCnooKS49fH6BdBUwLIIcz4XE3SiDzpw/edit?usp=sharing
#       - Copied over tyre information on Pirelli infographic to google spreadsheet

# %% [markdown]
# #### Pre-processing before performing Classification

# %%
# SS, S, M = 1
# S, M, H = 2
# SS, S, US = 3

for i,row in pirelli.iterrows(): 
    if (pirelli.loc[i,'Super Soft'] == 'Super Soft') & (pirelli.loc[i,'Soft'] == 'Soft') & (pirelli.loc[i,'Medium'] == "Medium"):  
        pirelli.loc[i,'mandatory combi'] = float(1)
    elif (pirelli.loc[i,'Soft'] == "Soft") & (pirelli.loc[i,'Medium'] == "Medium") & (pirelli.loc[i,'Hard'] == "Hard"):
        pirelli.loc[i,'mandatory combi'] = float(2)
    elif (pirelli.loc[i,'Super Soft'] == 'Super Soft') & (pirelli.loc[i,'Soft'] == 'Soft') & (pirelli.loc[i,'Ultra Soft'] == 'Ultra Soft'):
        pirelli.loc[i,'mandatory combi'] = float(3)
    elif (pirelli.loc[i,'Super Soft'] == 'Super Soft') & (pirelli.loc[i,'Soft'] == 'Soft') & (pirelli.loc[i,'Medium'] != "Medium"): 
        pirelli.loc[i,'mandatory combi'] = float(4)
    elif (pirelli.loc[i,'Super Soft'] != 'Super Soft') & (pirelli.loc[i,'Soft'] == 'Soft') & (pirelli.loc[i,'Medium'] != "Medium"): 
        pirelli.loc[i,'mandatory combi'] = float(5)
    elif (pirelli.loc[i,'Super Soft'] != 'Soft') & (pirelli.loc[i,'Medium'] == "Medium") & (pirelli.loc[i,'Hard'] == "Hard"): 
        pirelli.loc[i,'mandatory combi'] = float(6)
    else:
        pirelli.loc[i,'mandatory combi'] = float(7)

# %%
pirelli.sort_values(['name', 'year'])
# Out:
#     year                      name  Super Soft  Soft  Medium  Hard  \
# 39  2015      Abu Dhabi Grand Prix  Super Soft  Soft     NaN   NaN
# 20  2016      Abu Dhabi Grand Prix  Super Soft  Soft     NaN   NaN
# 59  2017      Abu Dhabi Grand Prix  Super Soft  Soft     NaN   NaN
# 21  2015     Australian Grand Prix         NaN  Soft  Medium   NaN
# 0   2016     Australian Grand Prix  Super Soft  Soft  Medium   NaN
# 40  2017     Australian Grand Prix  Super Soft  Soft     NaN   NaN
# 28  2015       Austrian Grand Prix  Super Soft  Soft     NaN   NaN
# 8   2016       Austrian Grand Prix  Super Soft  Soft     NaN   NaN
# 48  2017       Austrian Grand Prix  Super Soft  Soft     NaN   NaN
# 7   2016     Azerbaijan Grand Prix  Super Soft  Soft  Medium   NaN
# 47  2017     Azerbaijan Grand Prix  Super Soft  Soft  Medium   NaN
# 24  2015        Bahrain Grand Prix         NaN  Soft  Medium   NaN
# 1   2016        Bahrain Grand Prix  Super Soft  Soft  Medium   NaN
# 42  2017        Bahrain Grand Prix  Super Soft  Soft  Medium   NaN
# 31  2015        Belgian Grand Prix         NaN  Soft  Medium   NaN
# 13  2016        Belgian Grand Prix  Super Soft  Soft  Medium   NaN
# 51  2017        Belgian Grand Prix  Super Soft  Soft     NaN   NaN
# 38  2015      Brazilian Grand Prix         NaN  Soft  Medium   NaN
# 19  2016      Brazilian Grand Prix         NaN  Soft  Medium  Hard
# 58  2017      Brazilian Grand Prix  Super Soft  Soft  Medium   NaN
# 29  2015        British Grand Prix         NaN   NaN  Medium  Hard
# 9   2016        British Grand Prix         NaN  Soft  Medium  Hard
# 24         NaN              7.0
# 1          NaN              1.0
# 42         NaN              1.0
# 31         NaN              7.0
# 13         NaN              1.0
# 51  Ultra Soft              3.0
# 38         NaN              7.0
# 19         NaN              2.0
# 58         NaN              1.0
# 29         NaN              6.0
# 9          NaN              2.0
# 49         NaN              1.0
# 27         NaN              4.0
# 6   Ultra Soft              3.0
# 46  Ultra Soft              3.0
# 23         NaN              7.0
# 2          NaN              1.0
# 41         NaN              1.0
# 11         NaN              1.0
# 30         NaN              7.0
# 10         NaN              1.0
# 50         NaN              1.0
# 32         NaN              7.0
# 12         NaN              1.0
# 52         NaN              1.0
# 34         NaN              6.0
# 16         NaN              2.0
# 55         NaN              1.0
# 22         NaN              6.0
# 15         NaN              2.0
# 54         NaN              1.0
# 37         NaN              7.0
# 18         NaN              1.0
# 57  Ultra Soft              3.0
# 26         NaN              4.0
# 5   Ultra Soft              3.0
# 45  Ultra Soft              3.0
# 35         NaN              4.0
# 3          NaN              1.0
# 43  Ultra Soft              3.0
# 33         NaN              4.0
# 14  Ultra Soft              3.0
# 53  Ultra Soft              3.0
# 25         NaN              6.0
# 4          NaN              2.0
# 44         NaN              2.0
# 36         NaN              7.0
# 17         NaN              1.0
# 56  Ultra Soft              3.0

# %%
drivers_2016pt = pd.pivot_table(drivers_2016t, values='ratio', index=['driverRef'], columns=['tyre']).reset_index()
drivers_2016pt.rename(columns={"Hard": "H_m", "Intermediate": "I_m", "Medium":"M_m", "Soft": "S_m", "Super soft": "SS_m", "Ultra soft":"US_m", "Wet": "W_m"}, inplace=True)

# %%
track_new_agg = read_from_pickle(directory, "track_new_agg.pickle")
track_new_agg.drop(['Year'], axis=1, inplace=True)
track_new_agg.rename(columns={"Race": "name"}, inplace=True)

# %%
# Merge df containing driver-specific tyre degradation multiplier
df_final_1 = pd.merge(selected_sets, drivers_2016pt.reset_index(drop=True), on=['driverRef'], how='left')

# Merge df containing track-specific information(tyre wear rating etc.)
df_final_1 = pd.merge(df_final_1, track_new_agg.reset_index(drop=True), on=['name'], how='left')

# %%
XY = pd.merge(df_final_1, df_tyres[['year', 'name', 'driverRef', 'first set', 'second set', 'third set', 'fourth set']], on=['year', 'name', 'driverRef'], how='left')

# %%
# Null values because pirelli did not publish information of selected tyres for these races, althoug they did release the mandatory tyre set info for the race.
# I will instead inpute these values with the average values of races assigned the same mandatory tyre sets. 
# Each race has mandatory 3 tyre sets, so if there are more than 3 avg values, only 3 can be selected. Base it off the previos' year's tyre choice

# %%
XY = pd.merge(XY, pirelli[['year', 'name', 'mandatory combi']], on=['year', 'name'], how='left')
XY.groupby("mandatory combi").agg({'Medium':'mean', 'Soft':'mean', 'Super Soft':'mean', 'Ultra soft':'mean', 'Hard':'mean'})
# Out:
#                  Super Soft    Medium      Soft  Ultra soft      Hard
# mandatory combi
# 1.0                7.563291  1.588608  3.848101    0.000000  0.000000
# 2.0                0.000000  3.845455  7.163636    0.758621  1.738636
# 3.0                2.922222  0.000000  1.974074    8.103704  0.000000

# %%
# Find out which are the races with null values for driver selected sets
XY.drop_duplicates(subset=['year','name'], keep='first', inplace=False).sort_values("name")
# Out:
#      year                      name driverRef  Medium  Soft  Super Soft  \
# 798  2016      Abu Dhabi Grand Prix  hamilton     0.0   4.0         2.0
# 360  2017      Abu Dhabi Grand Prix  hamilton     0.0   2.0         2.0
# 776  2016     Australian Grand Prix  hamilton     1.0   6.0         6.0
# 340  2017     Australian Grand Prix  hamilton     NaN   NaN         NaN
# 600  2016       Austrian Grand Prix  hamilton     0.0   2.0         3.0
# 200  2017       Austrian Grand Prix  hamilton     0.0   2.0         3.0
# 622  2016     Azerbaijan Grand Prix  hamilton     1.0   4.0         8.0
# 220  2017     Azerbaijan Grand Prix  hamilton     1.0   4.0         8.0
# 754  2016        Bahrain Grand Prix  hamilton     1.0   6.0         6.0
# 320  2017        Bahrain Grand Prix  hamilton     NaN   NaN         NaN
# 534  2016        Belgian Grand Prix  hamilton     3.0   6.0         4.0
# 140  2017        Belgian Grand Prix  hamilton     0.0   4.0         3.0
# 0    2017      Brazilian Grand Prix    vettel     1.0   3.0         9.0
# 380  2016      Brazilian Grand Prix  hamilton     4.0   8.0         0.0
# 180  2017        British Grand Prix  hamilton     1.0   6.0         6.0
# 578  2016        British Grand Prix  hamilton     5.0   7.0         NaN
# 644  2016       Canadian Grand Prix  hamilton     NaN   3.0         2.0
# 240  2017       Canadian Grand Prix  hamilton     0.0   1.0         4.0
# 732  2016        Chinese Grand Prix  hamilton     4.0   4.0         5.0
# 160  2017      Hungarian Grand Prix    vettel     1.0   3.0         9.0
# 556  2016      Hungarian Grand Prix  hamilton     1.0   4.0         8.0
# 512  2016        Italian Grand Prix  hamilton     NaN   NaN         NaN
# 120  2017        Italian Grand Prix  hamilton     1.0   3.0         9.0
# 446  2016       Japanese Grand Prix  hamilton     2.0   8.0         NaN
# 60   2017       Japanese Grand Prix  hamilton     1.0   5.0         7.0
# 468  2016      Malaysian Grand Prix  hamilton     3.0   7.0         0.0
# 80   2017      Malaysian Grand Prix  hamilton     1.0   5.0         7.0
# 20   2017        Mexican Grand Prix  hamilton     0.0   1.0         3.0
# 402  2016        Mexican Grand Prix  hamilton     NaN   NaN         NaN
# 666  2016         Monaco Grand Prix  hamilton     0.0   1.0         2.0
# 260  2017         Monaco Grand Prix  hamilton     0.0   1.0         3.0
# 300  2017        Russian Grand Prix  hamilton     NaN   NaN         NaN
# 710  2016        Russian Grand Prix  hamilton     1.0   4.0         8.0
# 100  2017      Singapore Grand Prix  hamilton     0.0   2.0         2.0
# 490  2016      Singapore Grand Prix  hamilton     NaN   3.0         3.0
# 688  2016        Spanish Grand Prix  hamilton     5.0   7.0         0.0
# 280  2017        Spanish Grand Prix  hamilton     NaN   NaN         NaN
# 424  2016  United States Grand Prix  hamilton     3.0   4.0         6.0
# 40   2017  United States Grand Prix  hamilton     0.0   3.0         3.0
#
#      Ultra soft  Hard       H_m       I_m       ...         Tyre stress  \
# 798         7.0   0.0  0.976510  0.833021       ...                 2.0
# 360         9.0   0.0  0.976510  0.833021       ...                 2.0
# 776         0.0   0.0  0.976510  0.833021       ...                 1.0
# 340         NaN   NaN  0.976510  0.833021       ...                 1.0
# 600         8.0   0.0  0.976510  0.833021       ...                 2.0
# 200         8.0   0.0  0.976510  0.833021       ...                 2.0
# 622         0.0   0.0  0.976510  0.833021       ...                 3.0
# 220         0.0   0.0  0.976510  0.833021       ...                 3.0
# 754         0.0   0.0  0.976510  0.833021       ...                 3.0
# 320         NaN   NaN  0.976510  0.833021       ...                 3.0
# 534         NaN   NaN  0.976510  0.833021       ...                 5.0
# 140         6.0   0.0  0.976510  0.833021       ...                 5.0
# 0           0.0   0.0  1.107796  1.023426       ...                 3.0
# 380         0.0   1.0  0.976510  0.833021       ...                 3.0
# 180         0.0   0.0  0.976510  0.833021       ...                 5.0
# 578         NaN   1.0  0.976510  0.833021       ...                 5.0
# 644         8.0   NaN  0.976510  0.833021       ...                 2.0
# 240         8.0   0.0  0.976510  0.833021       ...                 2.0
# 732         0.0   0.0  0.976510  0.833021       ...                 4.0
# 160         0.0   0.0  1.107796  1.023426       ...                 3.0
# 556         NaN   NaN  0.976510  0.833021       ...                 3.0
# 512         NaN   NaN  0.976510  0.833021       ...                 5.0
# 120         0.0   0.0  0.976510  0.833021       ...                 5.0
# 446         3.0   NaN  0.976510  0.833021       ...                 5.0
# 60          0.0   0.0  0.976510  0.833021       ...                 5.0
# 468         0.0   3.0  0.976510  0.833021       ...                 4.0
# 80          0.0   0.0  0.976510  0.833021       ...                 4.0
# 20          9.0   0.0  0.976510  0.833021       ...                 3.0
# 402         NaN   NaN  0.976510  0.833021       ...                 3.0
# 666        10.0   0.0  0.976510  0.833021       ...                 1.0
# 260         9.0   0.0  0.976510  0.833021       ...                 1.0
# 300         NaN   NaN  0.976510  0.833021       ...                 2.0
# 710         NaN   NaN  0.976510  0.833021       ...                 2.0
# 100         9.0   0.0  0.976510  0.833021       ...                 1.0
# 490         7.0   NaN  0.976510  0.833021       ...                 1.0
# 688         0.0   1.0  0.976510  0.833021       ...                 4.0
# 280         NaN   NaN  0.976510  0.833021       ...                 4.0
# 424         NaN   NaN  0.976510  0.833021       ...                 3.0
# 40          7.0   0.0  0.976510  0.833021       ...                 3.0
#
#      Downforce  Lateral  Asphalt Abrasion  Number of laps     first set  \
# 798        3.0      3.0               2.0            55.0    Ultra soft
# 360        3.0      3.0               2.0            55.0    Ultra soft
# 776        4.0      1.0               3.0            58.0    Super soft
# 340        4.0      1.0               3.0            58.0    Ultra soft
# 600        3.0      3.0               1.0            71.0    Ultra soft
# 200        3.0      3.0               1.0            71.0    Super soft
# 622        2.0      2.0               1.0            51.0    Super soft
# 220        2.0      2.0               1.0            51.0    Super soft
# 754        3.0      3.0               5.0            57.0    Super soft
# 320        3.0      3.0               5.0            57.0    Super soft
# 534        2.0      4.0               3.0            44.0        Medium
# 140        2.0      4.0               3.0            44.0    Ultra soft
# 0          4.0      4.0               3.0            71.0    Super soft
# 380        4.0      4.0               3.0            71.0           Wet
# 180        4.0      5.0               3.0            52.0    Super soft
# 578        4.0      5.0               3.0            52.0           Wet
# 644        2.0      1.0               1.0            70.0    Ultra soft
# 240        2.0      1.0               1.0            70.0    Ultra soft
# 732        3.0      4.0               3.0            56.0          Soft
# 160        4.0      4.0               3.0            70.0    Super soft
# 556        4.0      4.0               3.0            70.0    Super soft
# 512        1.0      2.0               3.0            53.0          Soft
# 120        1.0      2.0               3.0            53.0    Super soft
# 446        3.0      5.0               3.0            53.0          Soft
# 60         3.0      5.0               3.0            53.0    Super soft
# 468        3.0      4.0               3.0            56.0          Soft
# 80         3.0      4.0               3.0            56.0    Super soft
# 20         4.0      2.0               2.0            71.0    Ultra soft
# 402        4.0      2.0               2.0            71.0          Soft
# 666        5.0      1.0               1.0            78.0           Wet
# 260        5.0      1.0               1.0            78.0    Ultra soft
# 300        4.0      5.0               2.0            53.0    Ultra soft
# 710        4.0      5.0               2.0            53.0    Super soft
# 100        5.0      2.0               3.0            61.0  Intermediate
# 490        5.0      2.0               3.0            61.0    Ultra soft
# 688        4.0      4.0               4.0            66.0          Soft
# 280        4.0      4.0               4.0            66.0          Soft
# 424        3.0      4.0               3.0            56.0          Soft
# 40         3.0      4.0               3.0            56.0    Ultra soft
#
#        second set   third set  fourth set  mandatory combi
# 798          Soft        Soft        None              3.0
# 360    Super soft        None        None              3.0
# 776        Medium        None        None              1.0
# 340          Soft        None        None              3.0
# 600          Soft        Soft        None              3.0
# 200    Ultra soft        None        None              3.0
# 622          Soft        None        None              1.0
# 220          Soft  Super soft        None              1.0
# 754        Medium  Super soft        Soft              1.0
# 320          Soft        Soft        None              1.0
# 534          Soft        Soft      Medium              1.0
# 140          Soft        Soft        None              3.0
# 0            Soft        None        None              1.0
# 380           Wet         Wet        None              2.0
# 180          Soft        None        None              1.0
# 578  Intermediate      Medium        None              2.0
# 644          Soft        None        None              3.0
# 240    Super soft        None        None              3.0
# 732          Soft  Super soft        Soft              1.0
# 160          Soft        None        None              1.0
# 556          Soft        Soft        None              1.0
# 512        Medium        None        None              1.0
# 120          Soft        None        None              1.0
# 446          Hard        Hard        None              2.0
# 60           Soft        None        None              1.0
# 468          Hard        None        None              2.0
# 80           Soft        None        None              1.0
# 20           Soft  Super soft        None              3.0
# 402        Medium        None        None              1.0
# 666    Ultra soft        None        None              3.0
# 260    Super soft        None        None              3.0
# 300    Super soft        None        None              3.0
# 710          Soft        None        None              1.0
# 100    Ultra soft        None        None              3.0
# 490          Soft        Soft  Super soft              3.0
# 688          None        None        None              2.0
# 280        Medium        Soft        None              2.0
# 424          Soft      Medium        None              1.0
# 40           Soft        None        None              3.0
#
# [39 rows x 27 columns]

# %%
for i, row in XY1.iterrows():
    if (XY1.loc[i,"clusters(pit strategy)"] == 1) & (XY1.loc[i,"name"] == "Australian Grand Prix") & (XY1.loc[i,"year"] == 2017):
        XY1.loc[i,"Super Soft"] =3 
        XY1.loc[i,"Ultra soft"] =8
        XY1.loc[i,"Soft"] =2
    elif (XY1.loc[i,"clusters(pit strategy)"] == 1) & (XY1.loc[i,"name"] == "Bahrain Grand Prix")  & (XY1.loc[i,"year"] == 2017):
        XY1.loc[i,"Super Soft"] =7
        XY1.loc[i,"Medium"] =2
        XY1.loc[i,"Soft"] = 4
    elif (XY1.loc[i,"clusters(pit strategy)"] == 1) & (XY1.loc[i,"name"] == "Italian Grand Prix")  & (XY1.loc[i,"year"] == 2016):
        XY1.loc[i,"Super Soft"] =7
        XY1.loc[i,"Medium"] =2
        XY1.loc[i,"Soft"] = 4
    elif (XY1.loc[i,"clusters(pit strategy)"] == 1) & (XY1.loc[i,"name"] == "Mexican Grand Prix")  & (XY1.loc[i,"year"] == 2016):
        XY1.loc[i,"Super Soft"] =7
        XY1.loc[i,"Medium"] =2
        XY1.loc[i,"Soft"] = 4
    elif (XY1.loc[i,"clusters(pit strategy)"] == 1) & (XY1.loc[i,"name"] == "Russian Grand Prix")  & (XY1.loc[i,"year"] == 2017):
        XY1.loc[i,"Super Soft"] =3 
        XY1.loc[i,"Ultra soft"] =8
        XY1.loc[i,"Soft"] =2
    elif (XY1.loc[i,"clusters(pit strategy)"] == 1) & (XY1.loc[i,"name"] == "Spanish Grand Prix")  & (XY1.loc[i,"year"] == 2017):
        XY1.loc[i,"Medium"] = 5
        XY1.loc[i,"Hard"] =1
        XY1.loc[i,"Soft"] = 7

# %%
def fillna_tyres(XY1):   
            
    # Null values in first set belong to drivers who DNS or did not finish the stint
    # Inpute first sets with "None" indicating they failed to finish the stint
    XY1['first set'] = XY1['first set'].fillna("None")
    XY1['second set'] = XY1['second set'].fillna("None")
    XY1['third set'] = XY1['third set'].fillna("None")
    XY1['fourth set'] = XY1['fourth set'].fillna("None")

    # Fill null values for the tyre columns with 0. Null values indicate the tyre was not part of the mandatory set
    tyrecols = ["Medium", "Soft", "Super Soft", "Ultra soft", "Hard"]
    for i in tyrecols:
        XY1[i] = XY1[i].fillna(0)  
        
    # New drivers in 2017 (stroll, gasly, hartley) do not have any tyre degration multiplier. 
    # Inpute their multipler as 1.
    XY1["H_m"] = XY1["H_m"].fillna(1)
    XY1["I_m"] = XY1["I_m"].fillna(1)
    XY1["M_m"] = XY1["M_m"].fillna(1)
    XY1["S_m"] = XY1["S_m"].fillna(1)
    XY1["SS_m"] = XY1["SS_m"].fillna(1)
    XY1["US_m"] = XY1["US_m"].fillna(1)
    XY1["W_m"] = XY1["W_m"].fillna(1)
    
    return XY1

# %%
XY = fillna_tyres(XY)

# %%
XY.isnull().sum()
# Out:
# year                 0
# name                 0
# driverRef            0
# Medium               0
# Soft                 0
# Super Soft           0
# Ultra soft           0
# Hard                 0
# H_m                  0
# I_m                  0
# M_m                  0
# S_m                  0
# SS_m                 0
# US_m                 0
# W_m                  0
# Track Temp(mean)     0
# Track Temp(range)    0
# Tyre stress          0
# Downforce            0
# Lateral              0
# Asphalt Abrasion     0
# Number of laps       0
# first set            0
# second set           0
# third set            0
# fourth set           0
# mandatory combi      0
# dtype: int64

# %% [markdown]
# ## Model Building
# ### Divide model by races allocated Combination1 (SS, S, M tyre set), Combination2 (S, M, H tyre set), Combination3 (SS, S, US tyre set)
# ### Further divide model by each stint. Assume that the maximum possible number of stints in a race is 4. In total, there are 12 separate classification models

# %%
# SS, S, M = 1
# S, M, H = 2
# SS, S, US = 3
XY.replace("Super Soft", "Super soft", inplace=True)

XY1 = XY.drop(['second set', 'third set', 'fourth set'], axis=1)
XY1 = XY1.drop(XY1[XY1['first set'] == 'None'].index)
XY1_c1 = XY1[XY1['mandatory combi'] == 1].reset_index()
XY1_c1 = XY1_c1.drop(["I_m", "US_m", "W_m", "H_m"], axis=1)
XY1_c2 = XY1[XY1['mandatory combi'] == 2].reset_index()
XY1_c2 = XY1_c2.drop(["I_m", "US_m", "W_m", "SS_m"], axis=1)
XY1_c3 = XY1[XY1['mandatory combi'] == 3].reset_index()
XY1_c3 = XY1_c3.drop(["I_m", "M_m", "W_m", "H_m"], axis=1)

XY2 = XY.drop(['first set', 'third set', 'fourth set'], axis=1)
XY2 = XY2.drop(XY2[XY2['second set'] == 'None'].index)
XY2_c1 = XY2[XY2['mandatory combi'] == 1].reset_index()
XY2_c1 = XY2_c1.drop(["I_m", "US_m", "W_m", "H_m"], axis=1)
XY2_c2 = XY2[XY2['mandatory combi'] == 2].reset_index()
XY2_c2 = XY2_c2.drop(["I_m", "US_m", "W_m", "SS_m"], axis=1)
XY2_c3 = XY2[XY2['mandatory combi'] == 3].reset_index()
XY2_c3 = XY2_c3.drop(["I_m", "M_m", "W_m", "H_m"], axis=1)

XY3 = XY.drop(['second set', 'first set', 'fourth set'], axis=1)
XY3 = XY3.drop(XY3[XY3['third set'] == 'None'].index)
XY3_c1 = XY3[XY3['mandatory combi'] == 1].reset_index()
XY3_c1 = XY3_c1.drop(["I_m", "US_m", "W_m", "H_m"], axis=1)
XY3_c2 = XY3[XY3['mandatory combi'] == 2].reset_index()
XY3_c2 = XY3_c2.drop(["I_m", "US_m", "W_m", "SS_m"], axis=1)
XY3_c3 = XY3[XY3['mandatory combi'] == 3].reset_index()
XY3_c3 = XY3_c3.drop(["I_m", "M_m", "W_m", "H_m"], axis=1)

XY4 = XY.drop(['second set', 'first set', 'third set'], axis=1)
XY4 = XY4.drop(XY4[XY4['fourth set'] == 'None'].index)
XY4_c1 = XY4[XY4['mandatory combi'] == 1].reset_index()
XY4_c1 = XY4_c1.drop(["I_m", "US_m", "W_m", "H_m"], axis=1)
XY4_c2 = XY4[XY4['mandatory combi'] == 2].reset_index()
XY4_c2 = XY4_c2.drop(["I_m", "US_m", "W_m", "SS_m"], axis=1)
XY4_c3 = XY4[XY4['mandatory combi'] == 3].reset_index()
XY4_c3 = XY4_c3.drop(["I_m", "M_m", "W_m", "H_m"], axis=1)

# %% [markdown]
# ### Classification of tyres to use for races assigned the mandatory tyre set of Super soft, Soft, Medium
#
# #### For Combination 1, what tyre type is each driver going to use for Stint 1?

# %%
XY1_c1_16 = XY1_c1[XY1_c1['year'] == 2016].reset_index(drop=True)
X1_c1 = XY1_c1_16.drop(['year', 'name', 'driverRef', 'first set', 'mandatory combi'], axis=1)
Y1_c1 = XY1_c1_16['first set']

XY1_c1_17 = XY1_c1[XY1_c1['year'] == 2017].reset_index(drop=True)
X1_c1_17 = XY1_c1_17.drop(['year', 'name', 'driverRef', 'first set', 'mandatory combi'], axis=1)
Y1_c1_17 = XY1_c1_17['first set']

# %%
XY1_c1_16.columns
# Out:
# Index([            u'index',              u'year',              u'name',
#                u'driverRef',            u'Medium',              u'Soft',
#               u'Super Soft',        u'Ultra soft',              u'Hard',
#                      u'M_m',               u'S_m',              u'SS_m',
#         u'Track Temp(mean)', u'Track Temp(range)',       u'Tyre stress',
#                u'Downforce',           u'Lateral',  u'Asphalt Abrasion',
#           u'Number of laps',         u'first set',   u'mandatory combi'],
#       dtype='object')

# %%
SS = StandardScaler()
X1_c1 = SS.fit_transform(X1_c1)
X1_c1_17 = SS.fit_transform(X1_c1_17)

# %%
XY1_c1['first set'].value_counts()
# Out:
# Super soft    263
# Soft          121
# Medium          6
# Name: first set, dtype: int64

# %%
# Train multinomial logistic regression model
def logreg(dftest, X_train, X_test, Y_train, Y_test):
    mul_lr = LogisticRegression(multi_class='multinomial', solver='newton-cg').fit(X_train, Y_train)

    print "Multinomial Logistic regression Train Accuracy :: ", accuracy_score(Y_train, mul_lr.predict(X_train))
    print "Multinomial Logistic regression Test Accuracy :: ", accuracy_score(Y_test, mul_lr.predict(X_test))
    
    p = pd.DataFrame(mul_lr.predict(X_test)).reset_index(drop=True)
    results = pd.concat([dftest, p], axis=1)
    
    return results

# %%
XY1_c1_res = logreg(XY1_c1_17, X1_c1, X1_c1_17, Y1_c1, Y1_c1_17)
XY1_c1_res
# Out:
# Multinomial Logistic regression Train Accuracy ::  0.693617021277
# Multinomial Logistic regression Test Accuracy ::  0.677419354839
#      index  year                   name   driverRef  Medium  Soft  Super Soft  \
# 0        0  2017   Brazilian Grand Prix      vettel     1.0   3.0         9.0
# 1        1  2017   Brazilian Grand Prix      bottas     1.0   4.0         8.0
# 2        2  2017   Brazilian Grand Prix   raikkonen     1.0   3.0         9.0
# 3        3  2017   Brazilian Grand Prix    hamilton     1.0   4.0         8.0
# 4        4  2017   Brazilian Grand Prix  verstappen     1.0   3.0         9.0
# 5        5  2017   Brazilian Grand Prix   ricciardo     1.0   4.0         8.0
# 6        7  2017   Brazilian Grand Prix      alonso     1.0   3.0         9.0
# 7        8  2017   Brazilian Grand Prix       perez     1.0   4.0         8.0
# 8        9  2017   Brazilian Grand Prix  hulkenberg     1.0   2.0        10.0
# 9       10  2017   Brazilian Grand Prix       sainz     1.0   2.0        10.0
# 10      11  2017   Brazilian Grand Prix       gasly     1.0   4.0         8.0
# 11      12  2017   Brazilian Grand Prix    ericsson     1.0   3.0         9.0
# 12      13  2017   Brazilian Grand Prix    wehrlein     1.0   3.0         9.0
# 13      14  2017   Brazilian Grand Prix    grosjean     1.0   4.0         8.0
# 14      15  2017   Brazilian Grand Prix      stroll     1.0   2.0        10.0
# 15      16  2017   Brazilian Grand Prix     hartley     1.0   4.0         8.0
# 16      18  2017   Brazilian Grand Prix   vandoorne     1.0   3.0         9.0
# 17      19  2017   Brazilian Grand Prix   magnussen     1.0   4.0         8.0
# 18      60  2017    Japanese Grand Prix    hamilton     1.0   5.0         7.0
# 19      61  2017    Japanese Grand Prix      bottas     2.0   4.0         7.0
# 20      62  2017    Japanese Grand Prix   ricciardo     1.0   3.0         9.0
# 21      63  2017    Japanese Grand Prix  verstappen     1.0   3.0         9.0
# 22      64  2017    Japanese Grand Prix      vettel     1.0   5.0         7.0
# 23      65  2017    Japanese Grand Prix   raikkonen     2.0   4.0         7.0
# 24      66  2017    Japanese Grand Prix       perez     3.0   3.0         7.0
# 25      67  2017    Japanese Grand Prix        ocon     3.0   3.0         7.0
# 26      68  2017    Japanese Grand Prix       massa     1.0   4.0         8.0
# 27      69  2017    Japanese Grand Prix      stroll     1.0   4.0         8.0
#
# 15            5.400000          3.0        4.0      4.0               3.0
# 16            5.400000          3.0        4.0      4.0               3.0
# 17            5.400000          3.0        4.0      4.0               3.0
# 18            3.366667          5.0        3.0      5.0               3.0
# 19            3.366667          5.0        3.0      5.0               3.0
# 20            3.366667          5.0        3.0      5.0               3.0
# 21            3.366667          5.0        3.0      5.0               3.0
# 22            3.366667          5.0        3.0      5.0               3.0
# 23            3.366667          5.0        3.0      5.0               3.0
# 24            3.366667          5.0        3.0      5.0               3.0
# 25            3.366667          5.0        3.0      5.0               3.0
# 26            3.366667          5.0        3.0      5.0               3.0
# 27            3.366667          5.0        3.0      5.0               3.0
# 28            3.366667          5.0        3.0      5.0               3.0
# 29            3.366667          5.0        3.0      5.0               3.0
# ..                 ...          ...        ...      ...               ...
# 125           4.950000          3.0        2.0      2.0               1.0
# 126           4.950000          3.0        2.0      2.0               1.0
# 127           4.950000          3.0        2.0      2.0               1.0
# 128           4.950000          3.0        2.0      2.0               1.0
# 129           4.950000          3.0        2.0      2.0               1.0
# 130           4.950000          3.0        2.0      2.0               1.0
# 131           4.950000          3.0        2.0      2.0               1.0
# 132           4.950000          3.0        2.0      2.0               1.0
# 133           4.950000          3.0        2.0      2.0               1.0
# 134           4.950000          3.0        2.0      2.0               1.0
# 135           4.950000          3.0        2.0      2.0               1.0
# 136           2.300000          3.0        3.0      3.0               5.0
# 137           2.300000          3.0        3.0      3.0               5.0
# 138           2.300000          3.0        3.0      3.0               5.0
# 139           2.300000          3.0        3.0      3.0               5.0
# 140           2.300000          3.0        3.0      3.0               5.0
# 141           2.300000          3.0        3.0      3.0               5.0
# 142           2.300000          3.0        3.0      3.0               5.0
# 143           2.300000          3.0        3.0      3.0               5.0
# 144           2.300000          3.0        3.0      3.0               5.0
# 145           2.300000          3.0        3.0      3.0               5.0
# 146           2.300000          3.0        3.0      3.0               5.0
# 147           2.300000          3.0        3.0      3.0               5.0
# 148           2.300000          3.0        3.0      3.0               5.0
# 149           2.300000          3.0        3.0      3.0               5.0
# 150           2.300000          3.0        3.0      3.0               5.0
# 151           2.300000          3.0        3.0      3.0               5.0
# 152           2.300000          3.0        3.0      3.0               5.0
# 153           2.300000          3.0        3.0      3.0               5.0
# 154           2.300000          3.0        3.0      3.0               5.0
#
#      Number of laps   first set  mandatory combi           0
# 0              71.0  Super soft              1.0  Super soft
# 1              71.0  Super soft              1.0  Super soft
# 2              71.0  Super soft              1.0  Super soft
# 3              71.0        Soft              1.0        Soft
# 4              71.0  Super soft              1.0  Super soft
# 5              71.0        Soft              1.0  Super soft
# 6              71.0  Super soft              1.0        Soft
# 7              71.0  Super soft              1.0  Super soft
# 8              71.0  Super soft              1.0  Super soft
# 9              71.0  Super soft              1.0  Super soft
# 10             71.0        Soft              1.0  Super soft
# 11             71.0        Soft              1.0  Super soft
# 12             71.0  Super soft              1.0  Super soft
# 13             71.0  Super soft              1.0  Super soft
# 14             71.0  Super soft              1.0  Super soft
# 15             71.0  Super soft              1.0  Super soft
# 16             71.0  Super soft              1.0  Super soft
# 17             71.0  Super soft              1.0        Soft
# 18             53.0  Super soft              1.0      Medium
# 19             53.0        Soft              1.0        Soft
# 20             53.0  Super soft              1.0        Soft
# 21             53.0  Super soft              1.0        Soft
# 22             53.0  Super soft              1.0        Soft
# 23             53.0        Soft              1.0        Soft
# 24             53.0  Super soft              1.0        Soft
# 25             53.0  Super soft              1.0        Soft
# 26             53.0  Super soft              1.0        Soft
# 27             53.0  Super soft              1.0        Soft
# 28             53.0  Super soft              1.0        Soft
# 29             53.0  Super soft              1.0        Soft
# ..              ...         ...              ...         ...
# 125            51.0  Super soft              1.0  Super soft
# 126            51.0  Super soft              1.0  Super soft
# 127            51.0        Soft              1.0  Super soft
# 128            51.0  Super soft              1.0  Super soft
# 129            51.0  Super soft              1.0  Super soft
# 130            51.0        Soft              1.0  Super soft
# 131            51.0  Super soft              1.0  Super soft
# 132            51.0  Super soft              1.0  Super soft
# 133            51.0  Super soft              1.0  Super soft
# 134            51.0  Super soft              1.0  Super soft
# 135            51.0        Soft              1.0  Super soft
# 136            57.0  Super soft              1.0  Super soft
# 137            57.0  Super soft              1.0  Super soft
# 138            57.0  Super soft              1.0  Super soft
# 139            57.0  Super soft              1.0  Super soft
# 140            57.0  Super soft              1.0  Super soft
# 141            57.0  Super soft              1.0  Super soft
# 142            57.0  Super soft              1.0  Super soft
# 143            57.0  Super soft              1.0  Super soft
# 144            57.0  Super soft              1.0  Super soft
# 145            57.0  Super soft              1.0  Super soft
# 146            57.0  Super soft              1.0  Super soft
# 147            57.0  Super soft              1.0  Super soft
# 148            57.0  Super soft              1.0  Super soft
# 149            57.0  Super soft              1.0  Super soft
# 150            57.0  Super soft              1.0  Super soft
# 151            57.0  Super soft              1.0  Super soft
# 152            57.0  Super soft              1.0  Super soft
# 153            57.0  Super soft              1.0  Super soft
# 154            57.0        Soft              1.0  Super soft
#
# [155 rows x 22 columns]

# %% [markdown]
# #### For Combination 1, what tyre type is each driver going to use for Stint 2?

# %%
XY2_c1['second set'].value_counts()
# Out:
# Soft          246
# Medium         61
# Super soft     57
# Name: second set, dtype: int64

# %%
XY2_c1_16 = XY2_c1[XY2_c1['year'] == 2016].reset_index(drop=True)
X2_c1 = XY2_c1_16.drop(['year', 'name', 'driverRef', 'second set', 'mandatory combi'], axis=1)
Y2_c1 = XY2_c1_16['second set']

XY2_c1_17 = XY2_c1[XY2_c1['year'] == 2017].reset_index(drop=True)
X2_c1_17 = XY2_c1_17.drop(['year', 'name', 'driverRef', 'second set', 'mandatory combi'], axis=1)
Y2_c1_17 = XY2_c1_17['second set']

X2_c1 = SS.fit_transform(X2_c1)
X2_c1_17 = SS.fit_transform(X2_c1_17)

# %%
XY2_c1_res = logreg(XY2_c1_17, X2_c1, X2_c1_17, Y2_c1, Y2_c1_17)
XY2_c1_res
# Out:
# Multinomial Logistic regression Train Accuracy ::  0.696428571429
# Multinomial Logistic regression Test Accuracy ::  0.55
#      index  year                   name   driverRef  Medium  Soft  Super Soft  \
# 
# 126           2.300000          3.0        3.0      3.0               5.0
# 127           2.300000          3.0        3.0      3.0               5.0
# 128           2.300000          3.0        3.0      3.0               5.0
# 129           2.300000          3.0        3.0      3.0               5.0
# 130           2.300000          3.0        3.0      3.0               5.0
# 131           2.300000          3.0        3.0      3.0               5.0
# 132           2.300000          3.0        3.0      3.0               5.0
# 133           2.300000          3.0        3.0      3.0               5.0
# 134           2.300000          3.0        3.0      3.0               5.0
# 135           2.300000          3.0        3.0      3.0               5.0
# 136           2.300000          3.0        3.0      3.0               5.0
# 137           2.300000          3.0        3.0      3.0               5.0
# 138           2.300000          3.0        3.0      3.0               5.0
# 139           2.300000          3.0        3.0      3.0               5.0
#
#      Number of laps  second set  mandatory combi           0
# 0              71.0        Soft              1.0      Medium
# 1              71.0        Soft              1.0        Soft
# 2              71.0        Soft              1.0      Medium
# 3              71.0  Super soft              1.0        Soft
# 4              71.0        Soft              1.0        Soft
# 5              71.0        Soft              1.0        Soft
# 6              71.0        Soft              1.0      Medium
# 7              71.0        Soft              1.0      Medium
# 8              71.0        Soft              1.0      Medium
# 9              71.0        Soft              1.0      Medium
# 10             71.0  Super soft              1.0        Soft
# 11             71.0  Super soft              1.0      Medium
# 12             71.0        Soft              1.0      Medium
# 13             71.0        Soft              1.0        Soft
# 14             71.0  Super soft              1.0      Medium
# 15             71.0        Soft              1.0        Soft
# 16             53.0        Soft              1.0        Soft
# 17             53.0  Super soft              1.0        Soft
# 18             53.0        Soft              1.0        Soft
# 19             53.0        Soft              1.0        Soft
# 20             53.0  Super soft              1.0        Soft
# 21             53.0        Soft              1.0      Medium
# 22             53.0        Soft              1.0        Soft
# 23             53.0        Soft              1.0        Soft
# 24             53.0        Soft              1.0        Soft
# 25             53.0        Soft              1.0      Medium
# 26             53.0        Soft              1.0        Soft
# 27             53.0        Soft              1.0        Soft
# 28             53.0        Soft              1.0        Soft
# 29             53.0        Soft              1.0        Soft
# ..              ...         ...              ...         ...
# 110            51.0        Soft              1.0        Soft
# 111            51.0        Soft              1.0        Soft
# 112            51.0        Soft              1.0        Soft
# 113            51.0        Soft              1.0        Soft
# 114            51.0        Soft              1.0        Soft
# 115            51.0        Soft              1.0        Soft
# 116            51.0  Super soft              1.0        Soft
# 117            51.0        Soft              1.0        Soft
# 118            51.0  Super soft              1.0        Soft
# 119            51.0        Soft              1.0        Soft
# 120            51.0        Soft              1.0        Soft
# 121            51.0        Soft              1.0        Soft
# 122            51.0  Super soft              1.0        Soft
# 123            57.0        Soft              1.0        Soft
# 124            57.0  Super soft              1.0        Soft
# 125            57.0        Soft              1.0        Soft
# 126            57.0  Super soft              1.0  Super soft
# 127            57.0  Super soft              1.0        Soft
# 128            57.0  Super soft              1.0        Soft
# 129            57.0  Super soft              1.0        Soft
# 130            57.0        Soft              1.0        Soft
# 131            57.0        Soft              1.0        Soft
# 132            57.0        Soft              1.0        Soft
# 133            57.0  Super soft              1.0        Soft
# 134            57.0        Soft              1.0        Soft
# 135            57.0  Super soft              1.0        Soft
# 136            57.0        Soft              1.0        Soft
# 137            57.0        Soft              1.0        Soft
# 138            57.0        Soft              1.0        Soft
# 139            57.0  Super soft              1.0  Super soft
#
# [140 rows x 22 columns]

# %% [markdown]
# #### For Combination 1, what tyre type is each driver going to use for Stint 3?

# %%
XY3_c1['third set'].value_counts()
# Out:
# Soft          85
# Super soft    72
# Medium        59
# Name: third set, dtype: int64

# %%
XY3_c1_16 = XY3_c1[XY3_c1['year'] == 2016].reset_index(drop=True)
X3_c1 = XY3_c1_16.drop(['year', 'name', 'driverRef', 'third set', 'mandatory combi'], axis=1)
Y3_c1 = XY3_c1_16['third set']

XY3_c1_17 = XY3_c1[XY3_c1['year'] == 2017].reset_index(drop=True)
X3_c1_17 = XY3_c1_17.drop(['year', 'name', 'driverRef', 'third set', 'mandatory combi'], axis=1)
Y3_c1_17 = XY3_c1_17['third set']

X3_c1 = SS.fit_transform(X3_c1)
X3_c1_17 = SS.fit_transform(X3_c1_17)

XY3_c1_res = logreg(XY3_c1_17, X3_c1, X3_c1_17, Y3_c1, Y3_c1_17)
XY3_c1_res
# Out:
# Multinomial Logistic regression Train Accuracy ::  0.590361445783
# Multinomial Logistic regression Test Accuracy ::  0.16
#     index  year                   name   driverRef  Medium  Soft  Super Soft  \
# 0       4  2017   Brazilian Grand Prix  verstappen     1.0   3.0         9.0
# 1       5  2017   Brazilian Grand Prix   ricciardo     1.0   4.0         8.0
# 2      15  2017   Brazilian Grand Prix      stroll     1.0   2.0        10.0
# 3      69  2017    Japanese Grand Prix      stroll     1.0   4.0         8.0
# 4      71  2017    Japanese Grand Prix   vandoorne     1.0   2.0        10.0
# 5      73  2017    Japanese Grand Prix       gasly     1.0   3.0         9.0
# 6      78  2017    Japanese Grand Prix    wehrlein     1.0   3.0         9.0
# 7      94  2017   Malaysian Grand Prix    grosjean     1.0   5.0         7.0
# 8      96  2017   Malaysian Grand Prix  hulkenberg     1.0   3.0         9.0
# 9     123  2017     Italian Grand Prix  verstappen     1.0   2.0        10.0
# 10    134  2017     Italian Grand Prix    grosjean     1.0   3.0         9.0
# 11    178  2017   Hungarian Grand Prix    wehrlein     1.0   3.0         9.0
# 12    179  2017   Hungarian Grand Prix    ericsson     1.0   3.0         9.0
# 13    183  2017     British Grand Prix  verstappen     1.0   4.0         8.0
# 14    184  2017     British Grand Prix      vettel     1.0   3.0         9.0
# 15    185  2017     British Grand Prix   raikkonen     1.0   3.0         9.0
# 16    189  2017     British Grand Prix      stroll     1.0   5.0         7.0
# 17    193  2017     British Grand Prix       kvyat     1.0   2.0        10.0
# 18    194  2017     British Grand Prix    grosjean     2.0   4.0         7.0
# 19    198  2017     British Grand Prix    wehrlein     1.0   5.0         7.0
# 20    220  2017  Azerbaijan Grand Prix    hamilton     1.0   4.0         8.0
# 21    221  2017  Azerbaijan Grand Prix      bottas     1.0   4.0         8.0
# 22    222  2017  Azerbaijan Grand Prix   ricciardo     2.0   3.0         8.0
# 23    224  2017  Azerbaijan Grand Prix      vettel     1.0   4.0         8.0
# 24    225  2017  Azerbaijan Grand Prix   raikkonen     1.0   4.0         8.0
# 25    226  2017  Azerbaijan Grand Prix       perez     1.0   3.0         9.0
# 26    227  2017  Azerbaijan Grand Prix        ocon     1.0   3.0         9.0
# 27    228  2017  Azerbaijan Grand Prix       massa     2.0   3.0         8.0
# 28    229  2017  Azerbaijan Grand Prix      stroll     1.0   4.0         8.0
# 29    230  2017  Azerbaijan Grand Prix      alonso     1.0   2.0        10.0
# 30    231  2017  Azerbaijan Grand Prix   vandoorne     1.0   2.0        10.0
# 31    232  2017  Azerbaijan Grand Prix       sainz     1.0   3.0         9.0
# 32    234  2017  Azerbaijan Grand Prix    grosjean     1.0   4.0         8.0
# 33    235  2017  Azerbaijan Grand Prix   magnussen     1.0   4.0         8.0
#
# 48           2.300000          3.0        3.0      3.0               5.0
# 49           2.300000          3.0        3.0      3.0               5.0
#
#     Number of laps   third set  mandatory combi           0
# 0             71.0  Super soft              1.0      Medium
# 1             71.0  Super soft              1.0        Soft
# 2             71.0  Super soft              1.0      Medium
# 3             53.0  Super soft              1.0      Medium
# 4             53.0  Super soft              1.0      Medium
# 5             53.0  Super soft              1.0      Medium
# 6             53.0        Soft              1.0      Medium
# 7             56.0  Super soft              1.0        Soft
# 8             56.0  Super soft              1.0        Soft
# 9             53.0  Super soft              1.0        Soft
# 10            53.0  Super soft              1.0        Soft
# 11            70.0        Soft              1.0        Soft
# 12            70.0  Super soft              1.0        Soft
# 13            52.0  Super soft              1.0      Medium
# 14            52.0  Super soft              1.0      Medium
# 15            52.0  Super soft              1.0      Medium
# 16            52.0  Super soft              1.0      Medium
# 17            52.0  Super soft              1.0      Medium
# 18            52.0  Super soft              1.0      Medium
# 19            52.0        Soft              1.0      Medium
# 20            51.0  Super soft              1.0        Soft
# 21            51.0  Super soft              1.0        Soft
# 22            51.0  Super soft              1.0        Soft
# 23            51.0  Super soft              1.0        Soft
# 24            51.0  Super soft              1.0        Soft
# 25            51.0  Super soft              1.0        Soft
# 26            51.0  Super soft              1.0  Super soft
# 27            51.0  Super soft              1.0      Medium
# 28            51.0  Super soft              1.0        Soft
# 29            51.0  Super soft              1.0  Super soft
# 30            51.0  Super soft              1.0        Soft
# 31            51.0  Super soft              1.0        Soft
# 32            51.0  Super soft              1.0        Soft
# 33            51.0  Super soft              1.0        Soft
# 34            51.0  Super soft              1.0        Soft
# 35            51.0  Super soft              1.0        Soft
# 36            51.0  Super soft              1.0        Soft
# 37            57.0        Soft              1.0  Super soft
# 38            57.0        Soft              1.0  Super soft
# 39            57.0  Super soft              1.0  Super soft
# 40            57.0        Soft              1.0  Super soft
# 41            57.0        Soft              1.0  Super soft
# 42            57.0        Soft              1.0  Super soft
# 43            57.0        Soft              1.0  Super soft
# 44            57.0        Soft              1.0  Super soft
# 45            57.0  Super soft              1.0  Super soft
# 46            57.0  Super soft              1.0  Super soft
# 47            57.0        Soft              1.0  Super soft
# 48            57.0  Super soft              1.0  Super soft
# 49            57.0  Super soft              1.0  Super soft
#
# [50 rows x 22 columns]

# %% [markdown]
# #### Try classifiers and sampling techniques without tuning hyperparameters to see which method is most promising

# %%
njobs = 4
rs=12

# %%
# create a dummy class for no sampling
class NoSampling(object):
    
    def fit_sample(self, X, y):
        return X, y

# try out a bunch of classifiers to see which is worth pursuing further
classifiers = [
    ['Logistic Regression', LogisticRegressionCV(multi_class='multinomial', solver='newton-cg', penalty='l2', max_iter= 500, Cs=10, cv=5, verbose=1, n_jobs=njobs, random_state=rs)],
    ['Random Forest', RandomForestClassifier(random_state=rs)],
    ['KNN', KNeighborsClassifier(n_jobs=njobs)],
    ['SVM (linear kernel)', SVC(kernel = 'linear', probability=True, verbose=1, random_state=rs)],
    ['SVM (rbf kernel)', SVC(kernel = 'rbf', probability=True, verbose=1, random_state=rs)]
]

# list out the sampling techniques that we are comparing
samplers = [
    ['No Sampling', NoSampling()],
    ['Random Oversampler', RandomOverSampler(random_state=rs)],
    ['SMOTE', SMOTE(ratio='minority', k_neighbors=3, random_state=rs)],
    ['SMOTE Tomek', SMOTETomek(random_state=rs)],
    ['SMOTE ENN', SMOTEENN(random_state=rs)]
]

# %%
def sampling_classifier_loop(train_X, test_X, train_y, test_y):

    # initialise dataframe for capturing coefficients of each feature
    l_classifier = []
    l_resampler = []
    l_recall = []
    l_precision = []

    # loop through all the classifiers except the logreg with class weights
    for classifier in classifiers[1:4]:
        #print '------------------------'
        #print classifier[0].upper()
        #print '------------------------'

        # loop through all the types of samplers
        for sampler in samplers:

            #print 
            #print sampler[0]
            #print '------------------------'

            # perform sampling
            train_X_sm, train_y_sm = sampler[1].fit_sample(train_X, train_y)

            # return dataframe of sampling results
            #print 'Ratio of training set:'
            #print pd.Series(train_y_sm).value_counts() /  pd.Series(train_y_sm).value_counts().sum()

            # fit model on train set
            classifier[1].fit(train_X_sm, train_y_sm)

            # use model to predict y
            y_pred = classifier[1].predict(test_X)

            # display confusion matrix & classification report
            #print 'Confusion Matrix:'
            #print confusion_matrix(test_y, y_pred)
            #print classification_report(test_y, y_pred)

            # save
            l_recall.append(recall_score(test_y, y_pred, average=None))
            l_precision.append(precision_score(test_y, y_pred, average=None))
            l_classifier.append(classifier[0])
            l_resampler.append(sampler[0])

    return l_recall, l_precision, l_classifier, l_resampler

# %%
# identify the combination of classifier and resampler that obtains the best recall
def results(l_recall, l_precision, l_classifier, l_resampler, Rcols, Pcols):
    df_results = pd.DataFrame({'Classifier': l_classifier, 'Resampler':l_resampler, 
                              'Recall':l_recall, 'Precision': l_precision})
    df_results = df_results[['Classifier', 'Resampler', 'Recall', 'Precision']]
    df_results[Rcols] = pd.DataFrame(df_results.Recall.values.tolist(), index= df_results.index)
    df_results[Pcols] = pd.DataFrame(df_results.Precision.values.tolist(), index= df_results.index)
    df_results = df_results.drop(['Recall', 'Precision'], axis=1)
    
    return df_results

# %%
# Combi 1 stint 1:
s1c1_recall, s1c1_precision, s1c1_classifier, s1c1_resampler = sampling_classifier_loop(X1_c1, X1_c1_17, Y1_c1, Y1_c1_17)

Rcols = ['recall: M', 'recall: Soft', 'recall: SS']
Pcols = ['precision: M', 'precision: Soft', 'precision: SS']
df_results_s1c1 = results(s1c1_recall, s1c1_precision, s1c1_classifier, s1c1_resampler, Rcols, Pcols)
df_results_s1c1

# SVM Linear Kernel
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]
#              Classifier           Resampler  recall: M  recall: Soft  \
# 0         Random Forest         No Sampling   0.448276      0.642857
# 1         Random Forest  Random Oversampler   0.000000      0.482759
# 2         Random Forest               SMOTE   0.000000      0.310345
# 3         Random Forest         SMOTE Tomek   0.000000      0.517241
# 4         Random Forest           SMOTE ENN   0.000000      0.655172
# 5                   KNN         No Sampling   0.000000      0.275862
# 6                   KNN  Random Oversampler   0.000000      0.379310
# 7                   KNN               SMOTE   0.000000      0.172414
# 8                   KNN         SMOTE Tomek   0.000000      0.206897
# 9                   KNN           SMOTE ENN   0.000000      0.310345
# 10  SVM (linear kernel)         No Sampling   0.000000      0.586207
# 11  SVM (linear kernel)  Random Oversampler   0.000000      0.517241
# 12  SVM (linear kernel)               SMOTE   0.000000      0.551724
# 13  SVM (linear kernel)         SMOTE Tomek   0.000000      0.413793
# 14  SVM (linear kernel)           SMOTE ENN   0.000000      0.689655
#
#     recall: SS  precision: M  precision: Soft  precision: SS
# 0          NaN      0.224138         0.835052            NaN
# 1     0.579365      0.000000         0.215385       0.829545
# 2     0.539683      0.000000         0.173077       0.800000
# 3     0.380952      0.000000         0.189873       0.800000
# 4     0.357143      0.000000         0.223529       0.882353
# 5     0.777778      0.000000         0.235294       0.823529
# 6     0.650794      0.000000         0.220000       0.828283
# 7     0.682540      0.000000         0.192308       0.834951
# 8     0.404762      0.000000         0.127660       0.796875
# 9     0.396825      0.000000         0.200000       0.847458
# 10    0.634921      0.000000         0.303571       0.879121
# 11    0.642857      0.000000         0.312500       0.870968
# 12    0.626984      0.000000         0.347826       0.877778
# 13    0.722222      0.000000         0.342857       0.858491
# 14    0.396825      0.000000         0.294118       0.909091

# %%
# Combi 1 stint 2:
s2c1_recall, s2c1_precision, s2c1_classifier, s2c1_resampler = sampling_classifier_loop(X2_c1, X2_c1_17, Y2_c1, Y2_c1_17)
df_results_s2c1 = results(s2c1_recall, s2c1_precision, s2c1_classifier, s2c1_resampler, Rcols, Pcols)
df_results_s2c1

# KNN + SMOTE gave the best results
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]
#              Classifier           Resampler  recall: M  recall: Soft  \
# 0         Random Forest         No Sampling        0.0      0.716981
# 1         Random Forest  Random Oversampler        1.0      0.716981
# 2         Random Forest               SMOTE        0.0      0.537736
# 3         Random Forest         SMOTE Tomek        0.0      0.330189
# 4         Random Forest           SMOTE ENN        0.0      0.207547
# 5                   KNN         No Sampling        0.0      0.924528
# 6                   KNN  Random Oversampler        0.0      0.547170
# 7                   KNN               SMOTE        0.0      0.603774
# 8                   KNN         SMOTE Tomek        0.0      0.415094
# 9                   KNN           SMOTE ENN        0.0      0.330189
# 10  SVM (linear kernel)         No Sampling        1.0      0.886792
# 11  SVM (linear kernel)  Random Oversampler        0.0      0.311321
# 12  SVM (linear kernel)               SMOTE        1.0      0.452830
# 13  SVM (linear kernel)         SMOTE Tomek        1.0      0.094340
# 14  SVM (linear kernel)           SMOTE ENN        0.0      0.132075
#
#     recall: SS  precision: M  precision: Soft  precision: SS
# 0     0.030303      0.000000         0.730769       0.142857
# 1     0.060606      0.025000         0.826087       0.250000
# 2     0.424242      0.000000         0.770270       0.304348
# 3     0.424242      0.000000         0.777778       0.291667
# 4     0.636364      0.000000         0.916667       0.308824
# 5     0.000000      0.000000         0.771654       0.000000
# 6     0.212121      0.000000         0.753247       0.205882
# 7     0.393939      0.000000         0.780488       0.265306
# 8     0.424242      0.000000         0.745763       0.237288
# 9     0.606061      0.000000         0.813953       0.263158
# 10    0.000000      0.055556         0.770492       0.000000
# 11    0.393939      0.000000         0.804878       0.295455
# 12    0.424242      0.043478         0.786885       0.250000
# 13    0.424242      0.014493         0.769231       0.241379
# 14    0.484848      0.000000         0.823529       0.266667

# %%
# Combi 1 stint 3:
s3c1_recall, s3c1_precision, s3c1_classifier, s3c1_resampler = sampling_classifier_loop(X3_c1, X3_c1_17, Y3_c1, Y3_c1_17)
df_results_s3c1 = results(s3c1_recall, s3c1_precision, s3c1_classifier, s3c1_resampler, Rcols, Pcols)
df_results_s3c1

# KNN + SMOTE gave the best results
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]
#              Classifier           Resampler  recall: M  recall: None  \
# 0         Random Forest         No Sampling        0.0      0.318182
# 1         Random Forest  Random Oversampler        0.0      0.254545
# 2         Random Forest               SMOTE        0.0      0.290909
# 3         Random Forest         SMOTE Tomek        0.0      0.163636
# 4         Random Forest           SMOTE ENN        0.0      0.000000
# 5                   KNN         No Sampling        0.0      0.463636
# 6                   KNN  Random Oversampler        0.0      0.381818
# 7                   KNN               SMOTE        0.0      0.354545
# 8                   KNN         SMOTE Tomek        0.0      0.327273
# 9                   KNN           SMOTE ENN        0.0      0.000000
# 10  SVM (linear kernel)         No Sampling        0.0      0.554545
# 11  SVM (linear kernel)  Random Oversampler        0.0      0.436364
# 12  SVM (linear kernel)               SMOTE        0.0      0.481818
# 13  SVM (linear kernel)         SMOTE Tomek        0.0      0.263636
# 14  SVM (linear kernel)           SMOTE ENN        0.0      0.145455
#
#     recall: Soft  recall: SS  precision: M  precision: None  precision: Soft  \
# 0       0.181818    0.205128           0.0         0.648148         0.048780
# 1       0.272727    0.051282           0.0         0.651163         0.056604
# 2       0.090909    0.179487           0.0         0.581818         0.038462
# 3       0.090909    0.461538           0.0         0.720000         0.111111
# 4       0.000000    0.717949           0.0         0.000000         0.000000
# 5       0.545455    0.076923           0.0         0.698630         0.146341
# 6       0.090909    0.282051           0.0         0.700000         0.043478
# 7       0.363636    0.461538           0.0         0.780000         0.142857
# 8       0.090909    0.282051           0.0         0.705882         0.040000
# 9       0.000000    0.871795           0.0         0.000000         0.000000
# 10      0.272727    0.000000           0.0         0.717647         0.073171
# 11      0.272727    0.153846           0.0         0.738462         0.096774
# 12      0.272727    0.179487           0.0         0.736111         0.083333
# 13      0.000000    0.461538           0.0         0.805556         0.000000
# 14      0.363636    0.589744           0.0         0.842105         0.190476
#
#     precision: SS
# 0        0.347826
# 1        0.125000
# 2        0.170732
# 3        0.268657
# 4        0.269231
# 5        0.428571
# 6        0.275000
# 7        0.346154
# 8        0.275000
# 9        0.295652
# 10       0.000000
# 11       0.285714
# 12       0.411765
# 13       0.360000
# 14       0.310811

# %% [markdown]
# ### Print prediction results

# %%
def print_pred_results(dftest, X_train, X_test, Y_train, Y_test, sampler, classifier):
    
    cXs_train_sm, cy_train_sm = sampler.fit_sample(X_train, Y_train)

    classifier.fit(cXs_train_sm, cy_train_sm)
    y_pred = classifier.predict(X_test)

    # Merge test prediction results back to test set
    p = pd.DataFrame(y_pred).reset_index(drop=True)
    results = pd.concat([dftest, p], axis=1)
    
    print "Train Accuracy :: ", accuracy_score(cy_train_sm, classifier.predict(cXs_train_sm))
    print "Test Accuracy :: ", accuracy_score(Y_test, y_pred)

    print 'Confusion Matrix:'
    print confusion_matrix(Y_test, y_pred)
    print classification_report(Y_test, y_pred) 
    
    return results

# %%
smote = SMOTE(ratio='minority', k=3, random_state=rs)
smoteen = SMOTEENN( random_state=rs)
smotetomek = SMOTETomek(random_state=rs)
knn = KNeighborsClassifier(n_jobs=njobs)
logreg = LogisticRegressionCV(multi_class='multinomial', solver='newton-cg', penalty='l2', max_iter= 500, Cs=10, cv=5, verbose=1, n_jobs=njobs, random_state=rs)

# %%
results_2017_c1_s1 = print_pred_results(XY1_c1_17, X1_c1, X1_c1_17, Y1_c1, Y1_c1_17, smotetomek, )
results_2017_c1_s1
# Out:
# Train Accuracy ::  0.856368563686
# Test Accuracy ::  0.574193548387
# Confusion Matrix:
# [[ 0  0  0]
#  [ 1 13 15]
#  [ 9 41 76]]
#              precision    recall  f1-score   support
#
#      Medium       0.00      0.00      0.00         0
#        Soft       0.24      0.45      0.31        29
#  Super soft       0.84      0.60      0.70       126
#
# avg / total       0.72      0.57      0.63       155
# /Users/dianaow/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
#      index  year                   name   driverRef  Medium  Soft  Super Soft  \
# 0        0  2017   Brazilian Grand Prix      vettel     1.0   3.0         9.0
# 1        1  2017   Brazilian Grand Prix      bottas     1.0   4.0         8.0
# 2        2  2017   Brazilian Grand Prix   raikkonen     1.0   3.0         9.0
# 3        3  2017   Brazilian Grand Prix    hamilton     1.0   4.0         8.0
# 4        4  2017   Brazilian Grand Prix  verstappen     1.0   3.0         9.0
# 5        5  2017   Brazilian Grand Prix   ricciardo     1.0   4.0         8.0
# 6        7  2017   Brazilian Grand Prix      alonso     1.0   3.0         9.0
# 7        8  2017   Brazilian Grand Prix       perez     1.0   4.0         8.0
# 8        9  2017   Brazilian Grand Prix  hulkenberg     1.0   2.0        10.0
# 9       10  2017   Brazilian Grand Prix       sainz     1.0   2.0        10.0
# 10      11  2017   Brazilian Grand Prix       gasly     1.0   4.0         8.0
# 11      12  2017   Brazilian Grand Prix    ericsson     1.0   3.0         9.0
# 12      13  2017   Brazilian Grand Prix    wehrlein     1.0   3.0         9.0
# 13      14  2017   Brazilian Grand Prix    grosjean     1.0   4.0         8.0
# 14      15  2017   Brazilian Grand Prix      stroll     1.0   2.0        10.0
# 15      16  2017   Brazilian Grand Prix     hartley     1.0   4.0         8.0
# 16      18  2017   Brazilian Grand Prix   vandoorne     1.0   3.0         9.0
# 17      19  2017   Brazilian Grand Prix   magnussen     1.0   4.0         8.0
# 18      60  2017    Japanese Grand Prix    hamilton     1.0   5.0         7.0
# 19      61  2017    Japanese Grand Prix      bottas     2.0   4.0         7.0
# 20      62  2017    Japanese Grand Prix   ricciardo     1.0   3.0         9.0
# 21      63  2017    Japanese Grand Prix  verstappen     1.0   3.0         9.0
# 22      64  2017    Japanese Grand Prix      vettel     1.0   5.0         7.0
# 23      65  2017    Japanese Grand Prix   raikkonen     2.0   4.0         7.0
# 24      66  2017    Japanese Grand Prix       perez     3.0   3.0         7.0
# 25      67  2017    Japanese Grand Prix        ocon     3.0   3.0         7.0
# 26      68  2017    Japanese Grand Prix       massa     1.0   4.0         8.0
# 27      69  2017    Japanese Grand Prix      stroll     1.0   4.0         8.0
#
# 24   1.215491  1.082196  Super soft              1.0        Soft
# 25   0.776618  0.932595  Super soft              1.0        Soft
# 26   0.959147  0.614245  Super soft              1.0  Super soft
# 27   1.000000  1.000000  Super soft              1.0  Super soft
# 28   1.018829  1.069176  Super soft              1.0  Super soft
# 29   0.767634  1.112083  Super soft              1.0        Soft
# ..        ...       ...         ...              ...         ...
# 125  1.000000  1.000000  Super soft              1.0  Super soft
# 126  1.018829  1.069176  Super soft              1.0  Super soft
# 127  0.767634  1.112083        Soft              1.0  Super soft
# 128  0.985030  1.032151  Super soft              1.0  Super soft
# 129  0.862162  0.945366  Super soft              1.0  Super soft
# 130  0.984553  1.048331        Soft              1.0        Soft
# 131  0.917130  0.984047  Super soft              1.0  Super soft
# 132  0.961426  1.072898  Super soft              1.0  Super soft
# 133  0.977303  1.015286  Super soft              1.0  Super soft
# 134  1.028564  1.002612  Super soft              1.0  Super soft
# 135  1.230801  0.943606        Soft              1.0  Super soft
# 136  0.882515  1.063797  Super soft              1.0        Soft
# 137  1.054087  0.942624  Super soft              1.0  Super soft
# 138  1.010958  1.172284  Super soft              1.0        Soft
# 139  0.911364  0.946199  Super soft              1.0  Super soft
# 140  1.176995  0.811017  Super soft              1.0  Super soft
# 141  1.124674  0.901477  Super soft              1.0  Super soft
# 142  1.215491  1.082196  Super soft              1.0        Soft
# 143  0.776618  0.932595  Super soft              1.0        Soft
# 144  0.959147  0.614245  Super soft              1.0  Super soft
# 145  1.000000  1.000000  Super soft              1.0        Soft
# 146  1.018829  1.069176  Super soft              1.0        Soft
# 147  0.985030  1.032151  Super soft              1.0        Soft
# 148  0.862162  0.945366  Super soft              1.0        Soft
# 149  0.984553  1.048331  Super soft              1.0        Soft
# 150  0.917130  0.984047  Super soft              1.0        Soft
# 151  0.961426  1.072898  Super soft              1.0        Soft
# 152  0.977303  1.015286  Super soft              1.0        Soft
# 153  1.028564  1.002612  Super soft              1.0        Soft
# 154  1.230801  0.943606        Soft              1.0        Soft
#
# [155 rows x 17 columns]

# %%
results_2017_c1_s2 = print_pred_results(XY2_c1_17, X2_c1, X2_c1_17, Y2_c1, Y2_c1_17, smote, knn)
results_2017_c1_s2
# Out:
# /Users/dianaow/anaconda2/lib/python2.7/site-packages/imblearn/utils/deprecation.py:50: DeprecationWarning: 'k' is deprecated from 0.2 and will be removed in 0.4. Use 'k_neighbors' instead.
#   category=DeprecationWarning)
# Train Accuracy ::  0.773529411765
# Test Accuracy ::  0.55
# Confusion Matrix:
# [[ 0  1  0]
#  [ 6 64 36]
#  [ 3 17 13]]
#              precision    recall  f1-score   support
#
#      Medium       0.00      0.00      0.00         1
#        Soft       0.78      0.60      0.68       106
#  Super soft       0.27      0.39      0.32        33
#
# avg / total       0.65      0.55      0.59       140
#      index  year                   name   driverRef  Medium  Soft  Super Soft  \
# 0        0  2017   Brazilian Grand Prix      vettel     1.0   3.0         9.0
# 1        1  2017   Brazilian Grand Prix      bottas     1.0   4.0         8.0
# 2        2  2017   Brazilian Grand Prix   raikkonen     1.0   3.0         9.0
# 3        3  2017   Brazilian Grand Prix    hamilton     1.0   4.0         8.0
# 4        4  2017   Brazilian Grand Prix  verstappen     1.0   3.0         9.0
#
# 130           2.300000          3.0        3.0      3.0               5.0
# 131           2.300000          3.0        3.0      3.0               5.0
# 132           2.300000          3.0        3.0      3.0               5.0
# 133           2.300000          3.0        3.0      3.0               5.0
# 134           2.300000          3.0        3.0      3.0               5.0
# 135           2.300000          3.0        3.0      3.0               5.0
# 136           2.300000          3.0        3.0      3.0               5.0
# 137           2.300000          3.0        3.0      3.0               5.0
# 138           2.300000          3.0        3.0      3.0               5.0
# 139           2.300000          3.0        3.0      3.0               5.0
#
#      Number of laps  second set  mandatory combi           0
# 0              71.0        Soft              1.0        Soft
# 1              71.0        Soft              1.0        Soft
# 2              71.0        Soft              1.0  Super soft
# 3              71.0  Super soft              1.0  Super soft
# 4              71.0        Soft              1.0  Super soft
# 5              71.0        Soft              1.0        Soft
# 6              71.0        Soft              1.0      Medium
# 7              71.0        Soft              1.0      Medium
# 8              71.0        Soft              1.0        Soft
# 9              71.0        Soft              1.0        Soft
# 10             71.0  Super soft              1.0  Super soft
# 11             71.0  Super soft              1.0  Super soft
# 12             71.0        Soft              1.0        Soft
# 13             71.0        Soft              1.0        Soft
# 14             71.0  Super soft              1.0  Super soft
# 15             71.0        Soft              1.0  Super soft
# 16             53.0        Soft              1.0        Soft
# 17             53.0  Super soft              1.0        Soft
# 18             53.0        Soft              1.0        Soft
# 19             53.0        Soft              1.0        Soft
# 20             53.0  Super soft              1.0      Medium
# 21             53.0        Soft              1.0      Medium
# 22             53.0        Soft              1.0        Soft
# 23             53.0        Soft              1.0        Soft
# 24             53.0        Soft              1.0      Medium
# 25             53.0        Soft              1.0        Soft
# 26             53.0        Soft              1.0        Soft
# 27             53.0        Soft              1.0        Soft
# 28             53.0        Soft              1.0        Soft
# 29             53.0        Soft              1.0        Soft
# ..              ...         ...              ...         ...
# 110            51.0        Soft              1.0  Super soft
# 111            51.0        Soft              1.0  Super soft
# 112            51.0        Soft              1.0        Soft
# 113            51.0        Soft              1.0        Soft
# 114            51.0        Soft              1.0  Super soft
# 115            51.0        Soft              1.0        Soft
# 116            51.0  Super soft              1.0        Soft
# 117            51.0        Soft              1.0        Soft
# 118            51.0  Super soft              1.0  Super soft
# 119            51.0        Soft              1.0        Soft
# 120            51.0        Soft              1.0  Super soft
# 121            51.0        Soft              1.0  Super soft
# 122            51.0  Super soft              1.0  Super soft
# 123            57.0        Soft              1.0        Soft
# 124            57.0  Super soft              1.0        Soft
# 125            57.0        Soft              1.0        Soft
# 126            57.0  Super soft              1.0  Super soft
# 127            57.0  Super soft              1.0      Medium
# 128            57.0  Super soft              1.0        Soft
# 129            57.0  Super soft              1.0        Soft
# 130            57.0        Soft              1.0  Super soft
# 131            57.0        Soft              1.0        Soft
# 132            57.0        Soft              1.0        Soft
# 133            57.0  Super soft              1.0        Soft
# 134            57.0        Soft              1.0        Soft
# 135            57.0  Super soft              1.0        Soft
# 136            57.0        Soft              1.0        Soft
# 137            57.0        Soft              1.0  Super soft
# 138            57.0        Soft              1.0        Soft
# 139            57.0  Super soft              1.0        Soft
#
# [140 rows x 22 columns]

# %%
results_2017_c1_s3 = print_pred_results(XY3_c1_17, X3_c1, X3_c1_17, Y3_c1, Y3_c1_17, smote, knn)
results_2017_c1_s3
# Out:
# /Users/dianaow/anaconda2/lib/python2.7/site-packages/imblearn/utils/deprecation.py:50: DeprecationWarning: 'k' is deprecated from 0.2 and will be removed in 0.4. Use 'k_neighbors' instead.
#   category=DeprecationWarning)
# Train Accuracy ::  0.705314009662
# Test Accuracy ::  0.36
# Confusion Matrix:
# [[ 0  0  0]
#  [ 5  6  0]
#  [ 9 18 12]]
#              precision    recall  f1-score   support
#
#      Medium       0.00      0.00      0.00         0
#        Soft       0.25      0.55      0.34        11
#  Super soft       1.00      0.31      0.47        39
#
# avg / total       0.83      0.36      0.44        50
#     index  year                   name   driverRef  Medium  Soft  Super Soft  \
# 0       4  2017   Brazilian Grand Prix  verstappen     1.0   3.0         9.0
# 1       5  2017   Brazilian Grand Prix   ricciardo     1.0   4.0         8.0
# 2      15  2017   Brazilian Grand Prix      stroll     1.0   2.0        10.0
# 3      69  2017    Japanese Grand Prix      stroll     1.0   4.0         8.0
# 4      71  2017    Japanese Grand Prix   vandoorne     1.0   2.0        10.0
# 5      73  2017    Japanese Grand Prix       gasly     1.0   3.0         9.0
# 6      78  2017    Japanese Grand Prix    wehrlein     1.0   3.0         9.0
# 7      94  2017   Malaysian Grand Prix    grosjean     1.0   5.0         7.0
# 8      96  2017   Malaysian Grand Prix  hulkenberg     1.0   3.0         9.0
# 9     123  2017     Italian Grand Prix  verstappen     1.0   2.0        10.0
# 10    134  2017     Italian Grand Prix    grosjean     1.0   3.0         9.0
# 11    178  2017   Hungarian Grand Prix    wehrlein     1.0   3.0         9.0
# 12    179  2017   Hungarian Grand Prix    ericsson     1.0   3.0         9.0
# 13    183  2017     British Grand Prix  verstappen     1.0   4.0         8.0
# 14    184  2017     British Grand Prix      vettel     1.0   3.0         9.0
# 15    185  2017     British Grand Prix   raikkonen     1.0   3.0         9.0
# 16    189  2017     British Grand Prix      stroll     1.0   5.0         7.0
# 17    193  2017     British Grand Prix       kvyat     1.0   2.0        10.0
# 18    194  2017     British Grand Prix    grosjean     2.0   4.0         7.0
# 19    198  2017     British Grand Prix    wehrlein     1.0   5.0         7.0
# 20    220  2017  Azerbaijan Grand Prix    hamilton     1.0   4.0         8.0
# 21    221  2017  Azerbaijan Grand Prix      bottas     1.0   4.0         8.0
# 22    222  2017  Azerbaijan Grand Prix   ricciardo     2.0   3.0         8.0
# 23    224  2017  Azerbaijan Grand Prix      vettel     1.0   4.0         8.0
# 24    225  2017  Azerbaijan Grand Prix   raikkonen     1.0   4.0         8.0
# 25    226  2017  Azerbaijan Grand Prix       perez     1.0   3.0         9.0
# 26    227  2017  Azerbaijan Grand Prix        ocon     1.0   3.0         9.0
# 27    228  2017  Azerbaijan Grand Prix       massa     2.0   3.0         8.0
# 28    229  2017  Azerbaijan Grand Prix      stroll     1.0   4.0         8.0
# 28         0.0   0.0  1.000000     ...             35.975000
# 29         0.0   0.0  0.677418     ...             35.975000
# 30         0.0   0.0  1.000000     ...             35.975000
# 31         0.0   0.0  1.131192     ...             35.975000
# 32         0.0   0.0  1.107727     ...             35.975000
# 33         0.0   0.0  0.788171     ...             35.975000
# 34         0.0   0.0  1.037634     ...             35.975000
# 35         0.0   0.0  1.014619     ...             35.975000
# 36         0.0   0.0  1.064800     ...             35.975000
# 37         0.0   0.0  0.851359     ...             29.150000
# 38         0.0   0.0  1.252126     ...             29.150000
# 39         0.0   0.0  1.045744     ...             29.150000
# 40         0.0   0.0  1.111487     ...             29.150000
# 41         0.0   0.0  1.009876     ...             29.150000
# 42         0.0   0.0  1.179297     ...             29.150000
# 43         0.0   0.0  0.838787     ...             29.150000
# 44         0.0   0.0  1.131398     ...             29.150000
# 45         0.0   0.0  0.677418     ...             29.150000
# 46         0.0   0.0  1.011507     ...             29.150000
# 47         0.0   0.0  1.107727     ...             29.150000
# 48         0.0   0.0  1.037634     ...             29.150000
# 49         0.0   0.0  0.913833     ...             29.150000
#
#     Track Temp(range)  Tyre stress  Downforce  Lateral  Asphalt Abrasion  \
# 0            5.400000          3.0        4.0      4.0               3.0
# 1            5.400000          3.0        4.0      4.0               3.0
# 2            5.400000          3.0        4.0      4.0               3.0
# 3            3.366667          5.0        3.0      5.0               3.0
# 4            3.366667          5.0        3.0      5.0               3.0
# 5            3.366667          5.0        3.0      5.0               3.0
# 6            3.366667          5.0        3.0      5.0               3.0
# 7            8.966667          4.0        3.0      4.0               3.0
# 8            8.966667          4.0        3.0      4.0               3.0
# 9            4.766667          5.0        1.0      2.0               3.0
# 10           4.766667          5.0        1.0      2.0               3.0
# 11           5.900000          3.0        4.0      4.0               3.0
# 12           5.900000          3.0        4.0      4.0               3.0
# 13           6.733333          5.0        4.0      5.0               3.0
# 14           6.733333          5.0        4.0      5.0               3.0
# 15           6.733333          5.0        4.0      5.0               3.0
# 16           6.733333          5.0        4.0      5.0               3.0
# 17           6.733333          5.0        4.0      5.0               3.0
# 18           6.733333          5.0        4.0      5.0               3.0
# 19           6.733333          5.0        4.0      5.0               3.0
# 20           4.950000          3.0        2.0      2.0               1.0
# 21           4.950000          3.0        2.0      2.0               1.0
# 22           4.950000          3.0        2.0      2.0               1.0
# 23           4.950000          3.0        2.0      2.0               1.0
# 24           4.950000          3.0        2.0      2.0               1.0
# 25           4.950000          3.0        2.0      2.0               1.0
# 26           4.950000          3.0        2.0      2.0               1.0
# 27           4.950000          3.0        2.0      2.0               1.0
# 28           4.950000          3.0        2.0      2.0               1.0
# 29           4.950000          3.0        2.0      2.0               1.0
# 30           4.950000          3.0        2.0      2.0               1.0
# 31           4.950000          3.0        2.0      2.0               1.0
# 32           4.950000          3.0        2.0      2.0               1.0
# 33           4.950000          3.0        2.0      2.0               1.0
# 34           4.950000          3.0        2.0      2.0               1.0
# 35           4.950000          3.0        2.0      2.0               1.0
# 36           4.950000          3.0        2.0      2.0               1.0
# 37           2.300000          3.0        3.0      3.0               5.0
# 38           2.300000          3.0        3.0      3.0               5.0
# 39           2.300000          3.0        3.0      3.0               5.0
# 40           2.300000          3.0        3.0      3.0               5.0
# 41           2.300000          3.0        3.0      3.0               5.0
# 42           2.300000          3.0        3.0      3.0               5.0
# 43           2.300000          3.0        3.0      3.0               5.0
# 44           2.300000          3.0        3.0      3.0               5.0
# 45           2.300000          3.0        3.0      3.0               5.0
# 46           2.300000          3.0        3.0      3.0               5.0
# 47           2.300000          3.0        3.0      3.0               5.0
# 48           2.300000          3.0        3.0      3.0               5.0
# 49           2.300000          3.0        3.0      3.0               5.0
#
#     Number of laps   third set  mandatory combi           0
# 0             71.0  Super soft              1.0        Soft
# 1             71.0  Super soft              1.0        Soft
# 2             71.0  Super soft              1.0        Soft
# 3             53.0  Super soft              1.0      Medium
# 4             53.0  Super soft              1.0      Medium
# 5             53.0  Super soft              1.0      Medium
# 6             53.0        Soft              1.0      Medium
# 7             56.0  Super soft              1.0        Soft
# 8             56.0  Super soft              1.0        Soft
# 9             53.0  Super soft              1.0      Medium
# 10            53.0  Super soft              1.0      Medium
# 11            70.0        Soft              1.0        Soft
# 12            70.0  Super soft              1.0  Super soft
# 13            52.0  Super soft              1.0        Soft
# 14            52.0  Super soft              1.0        Soft
# 15            52.0  Super soft              1.0      Medium
# 16            52.0  Super soft              1.0        Soft
# 17            52.0  Super soft              1.0        Soft
# 18            52.0  Super soft              1.0      Medium
# 19            52.0        Soft              1.0        Soft
# 20            51.0  Super soft              1.0  Super soft
# 21            51.0  Super soft              1.0  Super soft
# 22            51.0  Super soft              1.0  Super soft
# 23            51.0  Super soft              1.0        Soft
# 24            51.0  Super soft              1.0  Super soft
# 25            51.0  Super soft              1.0        Soft
# 26            51.0  Super soft              1.0  Super soft
# 27            51.0  Super soft              1.0      Medium
# 28            51.0  Super soft              1.0  Super soft
# 29            51.0  Super soft              1.0  Super soft
# 30            51.0  Super soft              1.0      Medium
# 31            51.0  Super soft              1.0  Super soft
# 32            51.0  Super soft              1.0  Super soft
# 33            51.0  Super soft              1.0        Soft
# 34            51.0  Super soft              1.0  Super soft
# 35            51.0  Super soft              1.0  Super soft
# 36            51.0  Super soft              1.0        Soft
# 37            57.0        Soft              1.0        Soft
# 38            57.0        Soft              1.0        Soft
# 39            57.0  Super soft              1.0        Soft
# 40            57.0        Soft              1.0      Medium
# 41            57.0        Soft              1.0      Medium
# 42            57.0        Soft              1.0      Medium
# 43            57.0        Soft              1.0        Soft
# 44            57.0        Soft              1.0      Medium
# 45            57.0  Super soft              1.0        Soft
# 46            57.0  Super soft              1.0        Soft
# 47            57.0        Soft              1.0        Soft
# 48            57.0  Super soft              1.0        Soft
# 49            57.0  Super soft              1.0        Soft
#
# [50 rows x 22 columns]

# %% [markdown]
# ### Findings: Classfication results indicate overfit as training accuracy is much higher than that of test accuracy. Furthermore , precision and recall scores are not ideal. Perhaps, the feature selection could be fine-tuned further to enable better classification results
